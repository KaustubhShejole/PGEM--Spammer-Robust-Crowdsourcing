# %% [markdown]
# In this repository, we have passage dataset ranking with features included
#
# For features, we will try various embedding models such as BERT, RoBERTa, etc.

# %%
# Out:
# /workspace/HCAI_Project/main/data/passage
