# %% [markdown]
# ### Setup

# %%
import numpy as np
import choix
from scipy.optimize import minimize
import scipy.stats as stats
import matplotlib.pyplot as plt
import random
from matplotlib import colors
import pandas as pd
import seaborn as sns
import pickle
import os
import sys


sys.path.append(os.path.abspath('../../'))
from metrics import compute_acc, compute_weighted_acc
from opt_fair import *

# %%
# !nvidia-smi
# Out:
# Tue Dec 16 11:34:03 2025
# +---------------------------------------------------------------------------------------+
# | NVIDIA-SMI 535.54.03              Driver Version: 535.54.03    CUDA Version: 12.5     |
# |-----------------------------------------+----------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |         Memory-Usage | GPU-Util  Compute M. |
# |                                         |                      |               MIG M. |
# |=========================================+======================+======================|
# |   0  NVIDIA A100 80GB PCIe          Off | 00000000:17:00.0 Off |                    0 |
# | N/A   59C    P0              75W / 300W |  23977MiB / 81920MiB |     20%      Default |
# |                                         |                      |             Disabled |
# +-----------------------------------------+----------------------+----------------------+
# |   1  NVIDIA A100 80GB PCIe          Off | 00000000:31:00.0 Off |                    0 |
# | N/A   72C    P0             314W / 300W |  63682MiB / 81920MiB |    100%      Default |
# |                                         |                      |             Disabled |
# +-----------------------------------------+----------------------+----------------------+
# |   2  NVIDIA A100 80GB PCIe          Off | 00000000:4B:00.0 Off |                    0 |
# | N/A   56C    P0              74W / 300W |  73247MiB / 81920MiB |      0%      Default |
# |                                         |                      |             Disabled |
# +-----------------------------------------+----------------------+----------------------+
# |   3  NVIDIA A100 80GB PCIe          Off | 00000000:CA:00.0 Off |                    0 |
# | N/A   61C    P0             249W / 300W |  16148MiB / 81920MiB |     84%      Default |
# |                                         |                      |             Disabled |
# +-----------------------------------------+----------------------+----------------------+
#
# +---------------------------------------------------------------------------------------+
# | Processes:                                                                            |
# |  GPU   GI   CI        PID   Type   Process name                            GPU Memory |
# |        ID   ID                                                             Usage      |
# |=======================================================================================|
# +---------------------------------------------------------------------------------------+

# %%
import os
import torch
os.environ["CUDA_VISIBLE_DEVICES"] = "0"
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print(device)
# Out:
# cuda

# %%
print(f"Current PyTorch version: {torch.__version__}")
print(f"CUDA available: {torch.cuda.is_available()}")
if torch.cuda.is_available():
    print(f"CUDA version: {torch.version.cuda}")
# Out:
# Current PyTorch version: 2.9.1+cu128
# CUDA available: True
# CUDA version: 12.8

# %%
with open("data/PassagePC.pickle", 'rb') as handle:
    PC_faceage = pickle.load(handle)    
with open("data/PassageDF.pickle", 'rb') as handle:
    df_faceage = pickle.load(handle)

# %%
df_faceage
# Out:
#                                                  label  score
# 0    a star. Our planet, Earth, orbits, or circles,...      1
# 1    Adam, We did not have plastic toys. I played w...      1
# 2    Who said the little owl. Who wants to hunt wit...      1
# 3    dead leaf. This is a mole. Moles burrow underg...      1
# 4    ereaddatagradepsenvironcomp.html Environment r...      1
# ..                                                 ...    ...
# 467  work over the summer on any changes they wish ...     12
# 468  between January and December plunged the Unite...     12
# 469  into a newly opened bank account. I was amazed...     12
# 470  occurring phenomenon, manmade by products are ...     12
# 471  question requires students to use context clue...     12
#
# [472 rows x 2 columns]

# %%
import opt_fair
all_pc_faceage  = opt_fair._pc_without_reviewers(PC_faceage)

size = len(df_faceage)
print(size)
classes = [0]*size
# Out:
# 472

# %%
print(len(all_pc_faceage))
# Out:
# 11763

# %% [markdown]
# ### PG EM

# %%
import random
from pgem import EMWrapper

max_iter = 500
pg = EMWrapper(PC_faceage, max_iter, device, 44)
r_est, beta_est, ll = pg.run_algorithm()
# Out:
# cuda
# [[272 348 283]
#  [415 354  33]
#  [465 311 144]
#  [ 49  85  54]
#  [415  20 331]]
# Device: cuda
# Initial Log-likelihood: -0.767009
# PG-EM Optimization:   0%|                   | 1/500 [00:00<01:35,  5.22it/s]
# Iter 000: Log-likelihood = -0.562702
# PG-EM Optimization:   2%|▎                  | 8/500 [00:00<00:27, 17.96it/s]
# Converged at iter 8, Log-likelihood change = 3.474900e-07

# %%
print(ll)
# Out:
# -0.523413492401323

# %%
stats.kendalltau(-1*r_est, df_faceage['score'])
# Out:
# SignificanceResult(statistic=-0.3686092224138372, pvalue=5.1935725002558044e-30)

# %%
print(compute_acc(df_faceage, 1*r_est, device))
# Out:
# 0.695236086845398
# /workspace/main/metrics.py:9: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.detach().clone() or sourceTensor.detach().clone().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   s = torch.tensor(predicted_scores, dtype=torch.float32, device=device)

# %%
print(compute_weighted_acc(df_faceage, 1*r_est, device))
# Out:
# 0.7565375566482544
# /workspace/main/metrics.py:50: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.detach().clone() or sourceTensor.detach().clone().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   s = torch.tensor(predicted_scores,

# %% [markdown]
# ### BT

# %%
# %%time
bt_scores = choix.opt_pairwise(size, all_pc_faceage, alpha=0, method='Newton-CG', initial_params=None, max_iter=None, tol=1e-05)
# Out:
# CPU times: user 47.5 s, sys: 2min 20s, total: 3min 7s
# Wall time: 7.55 s

# %%
stats.kendalltau(bt_scores, df_faceage['score'])
# Out:
# SignificanceResult(statistic=0.3408721163582005, pvalue=6.657069444052687e-26)

# %%
print(compute_acc(df_faceage, bt_scores, device))
# Out:
# 0.6804668307304382

# %%
print(compute_weighted_acc(df_faceage, bt_scores, device))
# Out:
# 0.74333256483078

# %% [markdown]
# ### BARP

# %%
# classes = [0]
FaceAge = opt_fair.BARP(data = PC_faceage, penalty = 0, classes = classes, device=device)

# %%
crowd_labels = pd.read_csv('data/passage_cleaned.csv')
num_reviewers =  crowd_labels['performer'].nunique()

# %%
# %%time
annot_bt_temp, annot_bias =  opt_fair._alternate_optim_torch(size, num_reviewers, FaceAge, iters = 100)
# Out:
# 100%|█████████████████████████████████████| 100/100 [01:14<00:00,  1.33it/s]
# CPU times: user 56.5 s, sys: 19.7 s, total: 1min 16s
# Wall time: 1min 16s

# %%
stats.kendalltau(annot_bt_temp.cpu(), df_faceage['score'])
# Out:
# SignificanceResult(statistic=0.36267695314604337, pvalue=4.1801087627048257e-29)

# %%
# import warnings
# warnings.filterwarnings('ignore')
print(compute_acc(df_faceage, annot_bt_temp.cpu(), device))
# Out:
# 0.6920762658119202
# /workspace/main/metrics.py:9: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.detach().clone() or sourceTensor.detach().clone().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   s = torch.tensor(predicted_scores, dtype=torch.float32, device=device)

# %%
print(compute_weighted_acc(df_faceage, annot_bt_temp.cpu(), device))
# Out:
# 0.7587689757347107
# /workspace/main/metrics.py:50: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.detach().clone() or sourceTensor.detach().clone().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   s = torch.tensor(predicted_scores,

# %% [markdown]
# ### RC

# %%
# %%time

rc_obj = RankCentrality(device)
A = rc_obj.matrix_of_comparisons(size, all_pc_faceage)
# print("A matrix done")
P = rc_obj.trans_prob(A)
# print("P matrix done")
pi = rc_obj.stationary_dist(P)
rank_centrality_scores = torch.log(pi).cpu().numpy()
# Out:
# CPU times: user 61.3 ms, sys: 53.5 ms, total: 115 ms
# Wall time: 112 ms

# %%
stats.kendalltau(rank_centrality_scores, df_faceage['score'])
# Out:
# SignificanceResult(statistic=0.2891796316210329, pvalue=4.669770558223192e-19)

# %%
print(compute_acc(df_faceage, rank_centrality_scores, device))
# Out:
# 0.6521800756454468

# %%
print(compute_weighted_acc(df_faceage, rank_centrality_scores, device))
# Out:
# 0.71303790807724

# %% [markdown]
# ### FactorBT

# %%
# %%time

factorbt_test = FactorBT(data = PC_faceage, penalty = 0, classes = classes, device=device)
factorbt_scores,y,z = factorbt_test.alternate_optim(iters=100)
# Out:
# 100%|█████████████████████████████████████| 100/100 [01:58<00:00,  1.18s/it]
# CPU times: user 1min 36s, sys: 21.8 s, total: 1min 58s
# Wall time: 1min 58s

# %%
stats.kendalltau(factorbt_scores.cpu(), df_faceage['score'])
# Out:
# SignificanceResult(statistic=0.3853247676997512, pvalue=1.223645231494805e-32)

# %%
print(compute_acc(df_faceage, factorbt_scores.cpu(), device))
# Out:
# 0.7040895819664001

# %%
print(compute_weighted_acc(df_faceage, factorbt_scores.cpu(), device))
# Out:
# 0.7693222761154175

# %% [markdown]
# ### CrowdBT

# %%
# %%time

crowdbt_test = CrowdBT(data = PC_faceage, penalty = 0, device=device)
crowdbt_scores, _ = crowdbt_test.alternate_optim(size, len(PC_faceage))
# Out:
# init done
# 100%|█████████████████████████████████████| 100/100 [01:31<00:00,  1.09it/s]
# CPU times: user 1min 15s, sys: 15.9 s, total: 1min 31s
# Wall time: 1min 31s

# %%
print(crowdbt_scores)
# Out:
#          1.7963e+00, -5.5267e-01,  8.3150e-01,  1.3822e+00,  1.4864e+00,
#         -7.8267e-01,  1.6143e+00,  4.4359e+00,  1.2882e-01, -7.5342e-01,
#          6.7773e-01, -1.5391e+00,  3.1560e+00,  3.3181e-01, -2.5561e-01,
#          1.0191e+00, -1.9011e+00,  1.1114e+00, -8.5243e-01, -9.8935e-01,
#         -1.2961e+00, -1.9286e+00, -8.1008e-01,  5.2765e-01,  8.3789e-02,
#         -1.2135e-02,  4.2097e-01, -9.8585e-01,  2.1931e+00,  3.0186e+00,
#          6.0470e+00, -1.6298e+00,  2.1562e+00,  2.0363e+00,  8.8812e-02,
#         -1.5494e-01,  1.6241e+00,  7.3133e-01,  1.0444e+00,  1.0682e+00,
#          2.0039e+00,  7.1459e-01, -1.2213e+00,  1.2752e-01,  1.8903e+00,
#          3.3828e-01, -3.1976e-01,  2.3033e+00, -1.2756e+00,  3.4427e-01,
#         -1.8494e-02, -9.1603e-01,  1.4335e+00,  6.9832e-01,  2.1204e-01,
#         -5.5311e-01,  1.5114e+00,  1.7543e+00,  1.6987e+00,  2.7194e-01,
#          1.6221e+00, -1.9961e-02, -3.3271e-01,  2.8256e+00, -1.5087e+00,
#         -1.8200e+00,  7.2025e-01,  5.6454e-01,  8.6724e-01,  2.1939e+00,
#          1.0345e+00, -4.4063e-01, -1.5886e-01,  1.6558e+00, -1.0392e+00,
#         -4.0672e-01,  1.4613e-01, -1.7335e+00,  2.5264e+00,  1.1993e+00,
#          1.8025e+00,  2.5708e+00,  6.4192e-01, -1.1808e+00,  1.3493e+00,
#         -4.9495e-02, -8.2502e-01,  1.3334e+00,  2.3012e+00, -3.6043e-01,
#          1.8741e+00,  3.2758e-01,  1.1519e+00,  2.5279e+00,  4.2413e-01,
#          1.0453e-01,  1.1574e+00,  2.5483e+00,  3.1633e+00,  1.6281e+00,
#         -1.8602e-01,  3.3732e-01,  9.3719e-01,  4.8857e+00,  2.6282e+00,
#          1.5776e-01,  2.5310e-01,  2.7913e+00,  4.1990e-01,  2.7005e+00,
#          2.9999e+00, -3.5016e-01, -5.3122e-01,  1.1097e+00,  1.2130e+00,
#          1.4381e+00,  3.7334e+00,  2.7273e+00,  2.0728e+00,  4.3216e-01,
#          2.0787e+00, -1.8153e-01,  1.5363e+00,  6.5886e-01, -5.5429e-01,
#          2.1220e+00,  3.5113e+00, -4.0114e-02,  2.6224e+00,  1.4527e+00,
#          8.6790e-01,  3.5800e+00, -4.7417e-01,  7.7015e-01,  2.3764e+00,
#          2.4482e+00,  2.7467e+00, -6.0853e-01,  1.3675e+00,  1.5462e+00,
#          1.2748e+00,  2.5718e+00,  5.3998e-01,  1.8280e+00, -7.0972e-01,
#          2.9092e+00, -2.6956e-01], device='cuda:0')

# %%
stats.kendalltau(crowdbt_scores.cpu(), df_faceage['score'])
# Out:
# SignificanceResult(statistic=0.386639901821448, pvalue=7.516780087725139e-33)

# %%
print(compute_acc(df_faceage, crowdbt_scores, device))
# Out:
# 0.7047861218452454

# %%
print(compute_weighted_acc(df_faceage, crowdbt_scores, device))
# Out:
# 0.7693936228752136
