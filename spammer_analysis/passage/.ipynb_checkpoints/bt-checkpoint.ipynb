# %% [markdown]
# ## Device Setup

# %%
# !nvidia-smi
# Out:
# Sat Dec 20 15:41:21 2025
# +---------------------------------------------------------------------------------------+
# | NVIDIA-SMI 535.54.03              Driver Version: 535.54.03    CUDA Version: 12.5     |
# |-----------------------------------------+----------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |         Memory-Usage | GPU-Util  Compute M. |
# |                                         |                      |               MIG M. |
# |=========================================+======================+======================|
# |   0  NVIDIA A100 80GB PCIe          Off | 00000000:17:00.0 Off |                    0 |
# | N/A   51C    P0              67W / 300W |    541MiB / 81920MiB |      0%      Default |
# |                                         |                      |             Disabled |
# +-----------------------------------------+----------------------+----------------------+
# |   1  NVIDIA A100 80GB PCIe          Off | 00000000:31:00.0 Off |                    0 |
# | N/A   35C    P0              67W / 300W |    511MiB / 81920MiB |      0%      Default |
# |                                         |                      |             Disabled |
# +-----------------------------------------+----------------------+----------------------+
# |   2  NVIDIA A100 80GB PCIe          Off | 00000000:4B:00.0 Off |                    0 |
# | N/A   53C    P0              49W / 300W |      4MiB / 81920MiB |      0%      Default |
# |                                         |                      |             Disabled |
# +-----------------------------------------+----------------------+----------------------+
# |   3  NVIDIA A100 80GB PCIe          Off | 00000000:CA:00.0 Off |                    0 |
# | N/A   68C    P0             285W / 300W |  57899MiB / 81920MiB |    100%      Default |
# |                                         |                      |             Disabled |
# +-----------------------------------------+----------------------+----------------------+
#
# +---------------------------------------------------------------------------------------+
# | Processes:                                                                            |
# |  GPU   GI   CI        PID   Type   Process name                            GPU Memory |
# |        ID   ID                                                             Usage      |
# |=======================================================================================|
# +---------------------------------------------------------------------------------------+

# %%
import os
import torch
os.environ["CUDA_VISIBLE_DEVICES"] = "0"
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print(device)
# Out:
# cuda

# %%
print(f"Current PyTorch version: {torch.__version__}")
print(f"CUDA available: {torch.cuda.is_available()}")
if torch.cuda.is_available():
    print(f"CUDA version: {torch.version.cuda}")
# Out:
# Current PyTorch version: 2.9.1+cu128
# CUDA available: True
# CUDA version: 12.8

# %% [markdown]
# ## Passage dataset

# %% [markdown]
# ***
# 10 random seeds: range(20, 30)
# for data creation for each type of spammer
#
# invoke bt
#
# get bt accuracy (+- std dev), wacc and tau
#
# save in results/spammer_type/bt.csv
# ***

# %%
import sys
sys.path.insert(0, "../")
sys.path.insert(1, "../../")

from spammer_types import *
from util import *
import opt_fair
from distribution_utils import crowd_bt_dist, logistic_preference_dist, comparisons_to_df, safe_kendalltau, to_numpy
from metrics import compute_acc, compute_weighted_acc
import choix

# %% [markdown]
# ### Get the original df of passage dataset

# %%
df_path = "../../real_data/passage/data/passage_cleaned.csv"

# %%
import pandas as pd
df = pd.read_csv(df_path)
def sort_df(df, column_name):
        # Sort by a specific column (replace 'column_name' with your column)
        df_sorted = df.sort_values(by=column_name, ascending=True)  # or ascending=False

        return df_sorted
df = sort_df(df, 'performer')
df[['left', 'right', 'label', 'performer']].head()
# Out:
#                                                  left  \
# 0   been wicked. They believed that the end of the...
# 20  school, you noticed that all the clocks read a...
# 19  foreign animals or plants may be taken into th...
# 18  many pennies did each child get Which computat...
# 17  direction of the Sun. The length in meters and...
#
#                                                 right  \
# 0   lichen Sect Content Linking Artid A snake coil...
# 20  man in the seat with me and the two women acro...
# 19  adhere to the wall. Using sizing that has been...
# 18  the picture on its cover. Write two or three s...
# 17  the ground going into the cave. Oh, my he said...
#
#                                                 label  performer
# 0   lichen Sect Content Linking Artid A snake coil...          5
# 20  man in the seat with me and the two women acro...          5
# 19  foreign animals or plants may be taken into th...          5
# 18  many pennies did each child get Which computat...          5
# 17  the ground going into the cave. Oh, my he said...          5

# %%
percents = [10, 20, 40, 60, 80]
# percents = [10]

# %%
import pickle

with open("../../real_data/passage/data/PassageDF.pickle", "rb") as handle:
    df_passage = pickle.load(handle)
df_passage
# Out:
#                                                  label  score
# 0    a star. Our planet, Earth, orbits, or circles,...      1
# 1    Adam, We did not have plastic toys. I played w...      1
# 2    Who said the little owl. Who wants to hunt wit...      1
# 3    dead leaf. This is a mole. Moles burrow underg...      1
# 4    ereaddatagradepsenvironcomp.html Environment r...      1
# ..                                                 ...    ...
# 467  work over the summer on any changes they wish ...     12
# 468  between January and December plunged the Unite...     12
# 469  into a newly opened bank account. I was amazed...     12
# 470  occurring phenomenon, manmade by products are ...     12
# 471  question requires students to use context clue...     12
#
# [472 rows x 2 columns]

# %%
size = len(df_passage)
print(size)
classes = [0] * size
# for faceage it would be classes = df_passage['gender']
# Out:
# 472

# %%
gt_df = df_passage

# %% [markdown]
# ### Addition of Random Guessors

# %%
spammer_type = "random"

# %%
csv_file = f"results/{spammer_type}/bt.csv"

# %%
import os
os.makedirs(f"results/{spammer_type}", exist_ok=True)

# %%
import csv
# -------------------------
# Write CSV header
# -------------------------
header = [
    "percent",
    "BT_acc_mean", "BT_acc_std",
    "BT_wacc_mean", "BT_wacc_std",
    "BT_tau_mean", "BT_tau_std"
]

with open(csv_file, mode='w', newline='') as f:
    writer = csv.writer(f)
    writer.writerow(header)

# %%
for percent in percents:
    # initialize metrics
    BT_accs, BT_waccs, BT_taus = [], [], []
    
    for sd in range(20, 30):
        
        # get df
        random_df, spammer_ids = add_random_spammer(df, percent, seed=sd)
        PC_faceage = df_to_pickle(random_df, df_passage)
        K = len(PC_faceage.keys())
        print(K)
        all_pc_faceage = opt_fair._pc_without_reviewers(PC_faceage)
        df_faceage = df_passage
        
        try:
            bt_scores = choix.opt_pairwise(size, all_pc_faceage, alpha=0, method='Newton-CG', initial_params=None, max_iter=None, tol=1e-05)
            bt_scores = to_numpy(bt_scores)
            bt_tau = safe_kendalltau(bt_scores, df_faceage['score'].to_numpy())
            if bt_tau < 0:
                bt_scores = -bt_scores
            bt_acc = compute_acc(df_faceage, bt_scores, device)
            bt_wacc = compute_weighted_acc(df_faceage, bt_scores, device)
            bt_tau = safe_kendalltau(bt_scores, df_faceage['score'].to_numpy())
        except Exception as e:
            print(f"BT failed: {e}")
            continue
        BT_accs.append(bt_acc)
        BT_waccs.append(bt_wacc)
        BT_taus.append(bt_tau)
    
    row = [
        percent,
        np.mean(BT_accs), np.std(BT_accs),
        np.mean(BT_waccs), np.std(BT_waccs),
        np.mean(BT_taus), np.std(BT_taus)
    ]
    with open(csv_file, mode='a', newline='') as f:
        writer = csv.writer(f)
        writer.writerow(row)
    print(
    f"BT | "
    f"Percent: {percent} |"
    f"Acc: {np.mean(BT_accs):.4f} ± {np.std(BT_accs):.4f} | "
    f"WAcc: {np.mean(BT_waccs):.4f} ± {np.std(BT_waccs):.4f} | "
    f"Tau: {np.mean(BT_taus):.4f} ± {np.std(BT_taus):.4f}"
)
# Out:
# Unique performers: 6864
# 6864
# BT | Percent: 10 |Acc: 0.6106 ± 0.0000 | WAcc: 0.6534 ± 0.0000 | Tau: 0.2088 ± 0.0000

# %% [markdown]
# ### Addition of Anti-Personas

# %%
spammer_type = "anti"

# %%
csv_file = f"results/{spammer_type}/bt.csv"

# %%
import os
os.makedirs(f"results/{spammer_type}", exist_ok=True)

# %%
import csv
# -------------------------
# Write CSV header
# -------------------------
header = [
    "percent",
    "BT_acc_mean", "BT_acc_std",
    "BT_wacc_mean", "BT_wacc_std",
    "BT_tau_mean", "BT_tau_std"
]

with open(csv_file, mode='w', newline='') as f:
    writer = csv.writer(f)
    writer.writerow(header)

# %%
for percent in percents:
    # initialize metrics
    BT_accs, BT_waccs, BT_taus = [], [], []
    
    for sd in range(20, 30):
        
        # get df
        random_df, spammer_ids = add_anti_personas(df, percent, seed=sd)
        PC_faceage = df_to_pickle(random_df, df_passage)
        K = len(PC_faceage.keys())
        print(K)
        all_pc_faceage = opt_fair._pc_without_reviewers(PC_faceage)
        df_faceage = df_passage
        
        try:
            bt_scores = choix.opt_pairwise(size, all_pc_faceage, alpha=0, method='Newton-CG', initial_params=None, max_iter=None, tol=1e-05)
            bt_scores = to_numpy(bt_scores)
            bt_tau = safe_kendalltau(bt_scores, df_faceage['score'].to_numpy())
            if bt_tau < 0:
                bt_scores = -bt_scores
            bt_acc = compute_acc(df_faceage, bt_scores, device)
            bt_wacc = compute_weighted_acc(df_faceage, bt_scores, device)
            bt_tau = safe_kendalltau(bt_scores, df_faceage['score'].to_numpy())
        except Exception as e:
            print(f"BT failed: {e}")
            continue
        BT_accs.append(bt_acc)
        BT_waccs.append(bt_wacc)
        BT_taus.append(bt_tau)
    
    row = [
        percent,
        np.mean(BT_accs), np.std(BT_accs),
        np.mean(BT_waccs), np.std(BT_waccs),
        np.mean(BT_taus), np.std(BT_taus)
    ]
    with open(csv_file, mode='a', newline='') as f:
        writer = csv.writer(f)
        writer.writerow(row)
    print(
    f"BT | "
    f"Percent: {percent} |"
    f"Acc: {np.mean(BT_accs):.4f} ± {np.std(BT_accs):.4f} | "
    f"WAcc: {np.mean(BT_waccs):.4f} ± {np.std(BT_waccs):.4f} | "
    f"Tau: {np.mean(BT_taus):.4f} ± {np.std(BT_taus):.4f}"
)
# Out:
# Unique performers: 6864
# 6864
# BT | Percent: 10 |Acc: 0.6807 ± 0.0000 | WAcc: 0.7437 ± 0.0000 | Tau: 0.3412 ± 0.0000

# %% [markdown]
# ### Addition of Left Position Biased Spammers

# %%
spammer_type = "left"

# %%
csv_file = f"results/{spammer_type}/bt.csv"

# %%
import os
os.makedirs(f"results/{spammer_type}", exist_ok=True)

# %%
import csv
# -------------------------
# Write CSV header
# -------------------------
header = [
    "percent",
    "BT_acc_mean", "BT_acc_std",
    "BT_wacc_mean", "BT_wacc_std",
    "BT_tau_mean", "BT_tau_std"
]

with open(csv_file, mode='w', newline='') as f:
    writer = csv.writer(f)
    writer.writerow(header)

# %%
for percent in percents:
    # initialize metrics
    BT_accs, BT_waccs, BT_taus = [], [], []
    
    for sd in range(20, 30):
        
        # get df
        random_df, spammer_ids = add_position_biased_spammers(df, percent, position_bias="left", seed=sd)
        PC_faceage = df_to_pickle(random_df, df_passage)
        K = len(PC_faceage.keys())
        print(K)
        all_pc_faceage = opt_fair._pc_without_reviewers(PC_faceage)
        df_faceage = df_passage
        
        try:
            bt_scores = choix.opt_pairwise(size, all_pc_faceage, alpha=0, method='Newton-CG', initial_params=None, max_iter=None, tol=1e-05)
            bt_scores = to_numpy(bt_scores)
            bt_tau = safe_kendalltau(bt_scores, df_faceage['score'].to_numpy())
            if bt_tau < 0:
                bt_scores = -bt_scores
            bt_acc = compute_acc(df_faceage, bt_scores, device)
            bt_wacc = compute_weighted_acc(df_faceage, bt_scores, device)
            bt_tau = safe_kendalltau(bt_scores, df_faceage['score'].to_numpy())
        except Exception as e:
            print(f"BT failed: {e}")
            continue
        BT_accs.append(bt_acc)
        BT_waccs.append(bt_wacc)
        BT_taus.append(bt_tau)
    
    row = [
        percent,
        np.mean(BT_accs), np.std(BT_accs),
        np.mean(BT_waccs), np.std(BT_waccs),
        np.mean(BT_taus), np.std(BT_taus)
    ]
    with open(csv_file, mode='a', newline='') as f:
        writer = csv.writer(f)
        writer.writerow(row)
    print(
    f"BT | "
    f"Percent: {percent} |"
    f"Acc: {np.mean(BT_accs):.4f} ± {np.std(BT_accs):.4f} | "
    f"WAcc: {np.mean(BT_waccs):.4f} ± {np.std(BT_waccs):.4f} | "
    f"Tau: {np.mean(BT_taus):.4f} ± {np.std(BT_taus):.4f}"
)
# Out:
# Unique performers: 6864
# 6864
# BT | Percent: 10 |Acc: 0.5279 ± 0.0000 | WAcc: 0.5364 ± 0.0000 | Tau: 0.0528 ± 0.0000

# %% [markdown]
# ### Addition of Right Position Biased Spammers

# %%
spammer_type = "right"

# %%
csv_file = f"results/{spammer_type}/bt.csv"

# %%
import os
os.makedirs(f"results/{spammer_type}", exist_ok=True)

# %%
import csv
# -------------------------
# Write CSV header
# -------------------------
header = [
    "percent",
    "BT_acc_mean", "BT_acc_std",
    "BT_wacc_mean", "BT_wacc_std",
    "BT_tau_mean", "BT_tau_std"
]

with open(csv_file, mode='w', newline='') as f:
    writer = csv.writer(f)
    writer.writerow(header)

# %%
for percent in percents:
    # initialize metrics
    BT_accs, BT_waccs, BT_taus = [], [], []
    
    for sd in range(20, 30):
        
        # get df
        random_df, spammer_ids = add_position_biased_spammers(df, percent, position_bias="right", seed=sd)
        PC_faceage = df_to_pickle(random_df, df_passage)
        K = len(PC_faceage.keys())
        print(K)
        all_pc_faceage = opt_fair._pc_without_reviewers(PC_faceage)
        df_faceage = df_passage
        
        try:
            bt_scores = choix.opt_pairwise(size, all_pc_faceage, alpha=0, method='Newton-CG', initial_params=None, max_iter=None, tol=1e-05)
            bt_scores = to_numpy(bt_scores)
            bt_tau = safe_kendalltau(bt_scores, df_faceage['score'].to_numpy())
            if bt_tau < 0:
                bt_scores = -bt_scores
            bt_acc = compute_acc(df_faceage, bt_scores, device)
            bt_wacc = compute_weighted_acc(df_faceage, bt_scores, device)
            bt_tau = safe_kendalltau(bt_scores, df_faceage['score'].to_numpy())
        except Exception as e:
            print(f"BT failed: {e}")
            continue
        BT_accs.append(bt_acc)
        BT_waccs.append(bt_wacc)
        BT_taus.append(bt_tau)
    
    row = [
        percent,
        np.mean(BT_accs), np.std(BT_accs),
        np.mean(BT_waccs), np.std(BT_waccs),
        np.mean(BT_taus), np.std(BT_taus)
    ]
    with open(csv_file, mode='a', newline='') as f:
        writer = csv.writer(f)
        writer.writerow(row)
    print(
    f"BT | "
    f"Percent: {percent} |"
    f"Acc: {np.mean(BT_accs):.4f} ± {np.std(BT_accs):.4f} | "
    f"WAcc: {np.mean(BT_waccs):.4f} ± {np.std(BT_waccs):.4f} | "
    f"Tau: {np.mean(BT_taus):.4f} ± {np.std(BT_taus):.4f}"
)
# Out:
# Unique performers: 6864
# 6864
# BT | Percent: 10 |Acc: 0.5612 ± 0.0000 | WAcc: 0.5756 ± 0.0000 | Tau: 0.1155 ± 0.0000

# %% [markdown]
# ### Addition of Equal proportion of all spammers

# %%
spammer_type = "equal"

# %%
csv_file = f"results/{spammer_type}/bt.csv"

# %%
import os
os.makedirs(f"results/{spammer_type}", exist_ok=True)

# %%
import csv
# -------------------------
# Write CSV header
# -------------------------
header = [
    "percent",
    "BT_acc_mean", "BT_acc_std",
    "BT_wacc_mean", "BT_wacc_std",
    "BT_tau_mean", "BT_tau_std"
]

with open(csv_file, mode='w', newline='') as f:
    writer = csv.writer(f)
    writer.writerow(header)

# %%
for percent in percents:
    # initialize metrics
    BT_accs, BT_waccs, BT_taus = [], [], []
    
    for sd in range(20, 30):
        
        # get df
        random_df, spammer_ids = add_equal_proportion_of_all_spammers(df, percent, seed=sd)
        PC_faceage = df_to_pickle(random_df, df_passage)
        K = len(PC_faceage.keys())
        print(K)
        all_pc_faceage = opt_fair._pc_without_reviewers(PC_faceage)
        df_faceage = df_passage
        
        try:
            bt_scores = choix.opt_pairwise(size, all_pc_faceage, alpha=0, method='Newton-CG', initial_params=None, max_iter=None, tol=1e-05)
            bt_scores = to_numpy(bt_scores)
            bt_tau = safe_kendalltau(bt_scores, df_faceage['score'].to_numpy())
            if bt_tau < 0:
                bt_scores = -bt_scores
            bt_acc = compute_acc(df_faceage, bt_scores, device)
            bt_wacc = compute_weighted_acc(df_faceage, bt_scores, device)
            bt_tau = safe_kendalltau(bt_scores, df_faceage['score'].to_numpy())
        except Exception as e:
            print(f"BT failed: {e}")
            continue
        BT_accs.append(bt_acc)
        BT_waccs.append(bt_wacc)
        BT_taus.append(bt_tau)
    
    row = [
        percent,
        np.mean(BT_accs), np.std(BT_accs),
        np.mean(BT_waccs), np.std(BT_waccs),
        np.mean(BT_taus), np.std(BT_taus)
    ]
    with open(csv_file, mode='a', newline='') as f:
        writer = csv.writer(f)
        writer.writerow(row)
    print(
    f"BT | "
    f"Percent: {percent} |"
    f"Acc: {np.mean(BT_accs):.4f} ± {np.std(BT_accs):.4f} | "
    f"WAcc: {np.mean(BT_waccs):.4f} ± {np.std(BT_waccs):.4f} | "
    f"Tau: {np.mean(BT_taus):.4f} ± {np.std(BT_taus):.4f}"
)
# Out:
# Unique performers: 6864
# 6864
# BT | Percent: 10 |Acc: 0.6037 ± 0.0000 | WAcc: 0.6439 ± 0.0000 | Tau: 0.1959 ± 0.0000
