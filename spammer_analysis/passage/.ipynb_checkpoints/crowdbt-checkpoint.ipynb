# %% [markdown]
# ***
# 10 random seeds: range(20, 30)
# for data creation for each type of spammer
#
# invoke crowdbt for 10 random seeds: range(10)
#
# get crowdbt accuracy (+- std dev), wacc and tau
#
# save in results/spammer_type/crowdbt.csv
# ***

# %% [markdown]
# ## Device Setup

# %%
# !nvidia-smi
# Out:
# Sun Dec 21 08:13:40 2025
# +---------------------------------------------------------------------------------------+
# | NVIDIA-SMI 535.54.03              Driver Version: 535.54.03    CUDA Version: 12.5     |
# |-----------------------------------------+----------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |         Memory-Usage | GPU-Util  Compute M. |
# |                                         |                      |               MIG M. |
# |=========================================+======================+======================|
# |   0  NVIDIA A100 80GB PCIe          Off | 00000000:17:00.0 Off |                    0 |
# | N/A   50C    P0              67W / 300W |    529MiB / 81920MiB |      0%      Default |
# |                                         |                      |             Disabled |
# +-----------------------------------------+----------------------+----------------------+
# |   1  NVIDIA A100 80GB PCIe          Off | 00000000:31:00.0 Off |                    0 |
# | N/A   38C    P0              48W / 300W |      4MiB / 81920MiB |      0%      Default |
# |                                         |                      |             Disabled |
# +-----------------------------------------+----------------------+----------------------+
# |   2  NVIDIA A100 80GB PCIe          Off | 00000000:4B:00.0 Off |                    0 |
# | N/A   74C    P0             288W / 300W |  49971MiB / 81920MiB |     99%      Default |
# |                                         |                      |             Disabled |
# +-----------------------------------------+----------------------+----------------------+
# |   3  NVIDIA A100 80GB PCIe          Off | 00000000:CA:00.0 Off |                    0 |
# | N/A   41C    P0              73W / 300W |   2118MiB / 81920MiB |     97%      Default |
# |                                         |                      |             Disabled |
# +-----------------------------------------+----------------------+----------------------+
#
# +---------------------------------------------------------------------------------------+
# | Processes:                                                                            |
# |  GPU   GI   CI        PID   Type   Process name                            GPU Memory |
# |        ID   ID                                                             Usage      |
# |=======================================================================================|
# +---------------------------------------------------------------------------------------+

# %%
import os
import torch
os.environ["CUDA_VISIBLE_DEVICES"] = "1"
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print(device)
# Out:
# cuda

# %%
print(f"Current PyTorch version: {torch.__version__}")
print(f"CUDA available: {torch.cuda.is_available()}")
if torch.cuda.is_available():
    print(f"CUDA version: {torch.version.cuda}")
# Out:
# Current PyTorch version: 2.9.1+cu128
# CUDA available: True
# CUDA version: 12.8

# %% [markdown]
# ### Importing CrowdBT

# %%
import sys
sys.path.insert(0, "../")
sys.path.insert(1, "../../")

from spammer_types import *
from util import *
import opt_fair
from distribution_utils import crowd_bt_dist, logistic_preference_dist, comparisons_to_df, safe_kendalltau, to_numpy
from metrics import compute_acc, compute_weighted_acc
from pgem import EMWrapper

# %% [markdown]
# ## Passage dataset

# %% [markdown]
# ### Get the original df of passage dataset

# %%
df_path = "../../real_data/passage/data/passage_cleaned.csv"

# %%
import pandas as pd
df = pd.read_csv(df_path)
def sort_df(df, column_name):
        # Sort by a specific column (replace 'column_name' with your column)
        df_sorted = df.sort_values(by=column_name, ascending=True)  # or ascending=False

        return df_sorted
df = sort_df(df, 'performer')
df[['left', 'right', 'label', 'performer']].head()
# Out:
#                                                  left  \
# 0   been wicked. They believed that the end of the...
# 20  school, you noticed that all the clocks read a...
# 19  foreign animals or plants may be taken into th...
# 18  many pennies did each child get Which computat...
# 17  direction of the Sun. The length in meters and...
#
#                                                 right  \
# 0   lichen Sect Content Linking Artid A snake coil...
# 20  man in the seat with me and the two women acro...
# 19  adhere to the wall. Using sizing that has been...
# 18  the picture on its cover. Write two or three s...
# 17  the ground going into the cave. Oh, my he said...
#
#                                                 label  performer
# 0   lichen Sect Content Linking Artid A snake coil...          5
# 20  man in the seat with me and the two women acro...          5
# 19  foreign animals or plants may be taken into th...          5
# 18  many pennies did each child get Which computat...          5
# 17  the ground going into the cave. Oh, my he said...          5

# %%
percents = [10, 20, 40, 60, 80]
# percents = [10]

# %%
import pickle

with open("../../real_data/passage/data/PassageDF.pickle", "rb") as handle:
    df_passage = pickle.load(handle)
df_passage
# Out:
#                                                  label  score
# 0    a star. Our planet, Earth, orbits, or circles,...      1
# 1    Adam, We did not have plastic toys. I played w...      1
# 2    Who said the little owl. Who wants to hunt wit...      1
# 3    dead leaf. This is a mole. Moles burrow underg...      1
# 4    ereaddatagradepsenvironcomp.html Environment r...      1
# ..                                                 ...    ...
# 467  work over the summer on any changes they wish ...     12
# 468  between January and December plunged the Unite...     12
# 469  into a newly opened bank account. I was amazed...     12
# 470  occurring phenomenon, manmade by products are ...     12
# 471  question requires students to use context clue...     12
#
# [472 rows x 2 columns]

# %%
size = len(df_passage)
print(size)
classes = [0] * size
# for faceage it would be classes = df_passage['gender']
# Out:
# 472

# %%
gt_df = df_passage

# %% [markdown]
# ### Addition of Random Guessors

# %%
spammer_type = "random"

# %%
csv_file = f"results/{spammer_type}/crowdbt.csv"

# %%
import os
os.makedirs(f"results/{spammer_type}", exist_ok=True)

# %%
import csv
# -------------------------
# Write CSV header
# -------------------------
header = [
    "percent",
    "CrowdBT_acc_mean", "CrowdBT_acc_std",
    "CrowdBT_wacc_mean", "CrowdBT_wacc_std",
    "CrowdBT_tau_mean", "CrowdBT_tau_std"
]

with open(csv_file, mode='w', newline='') as f:
    writer = csv.writer(f)
    writer.writerow(header)

# %%
max_iter_pgem = 100

for percent in percents:
    # initialize metrics
    CrowdBT_accs, CrowdBT_waccs, CrowdBT_taus = [], [], []
    
    for sd in range(20, 21):
        
        # get df
        random_df, spammer_ids = add_random_spammer(df, percent, seed=sd)
        PC_faceage = df_to_pickle(random_df, df_passage)
        K = len(PC_faceage.keys())
        print(K)
        
        for seed in range(10):
            try:
                crowdbt_test = opt_fair.CrowdBT_3_0(data=PC_faceage, penalty=0, device=device, random_seed=seed)
                crowdbt_scores, _ = crowdbt_test.alternate_optim(size, K)
                r_est = to_numpy(crowdbt_scores)
                if np.isnan(r_est).any():
                    continue
                CrowdBT_tau = safe_kendalltau(r_est, gt_df['score'].to_numpy())
                if CrowdBT_tau < 0:
                    r_est = -r_est
                CrowdBT_acc = compute_acc(gt_df, r_est, device)
                CrowdBT_wacc = compute_weighted_acc(gt_df, r_est, device)
                CrowdBT_tau = safe_kendalltau(r_est, gt_df['score'].to_numpy())
            
            except Exception as e:
                print(f"CrowdBT failed due to {e}")
                continue
            CrowdBT_accs.append(CrowdBT_acc)
            CrowdBT_waccs.append(CrowdBT_wacc)
            CrowdBT_taus.append(CrowdBT_tau)
    
    row = [
        percent,
        np.mean(CrowdBT_accs), np.std(CrowdBT_accs),
        np.mean(CrowdBT_waccs), np.std(CrowdBT_waccs),
        np.mean(CrowdBT_taus), np.std(CrowdBT_taus)
    ]
    
    with open(csv_file, mode='a', newline='') as f:
        writer = csv.writer(f)
        writer.writerow(row)
    print(
    f"CrowdBT | "
    f"Percent: {percent} |"
    f"Acc: {np.mean(CrowdBT_accs):.4f} ± {np.std(CrowdBT_accs):.4f} | "
    f"WAcc: {np.mean(CrowdBT_waccs):.4f} ± {np.std(CrowdBT_waccs):.4f} | "
    f"Tau: {np.mean(CrowdBT_taus):.4f} ± {np.std(CrowdBT_taus):.4f}")
# Out:
# Unique performers: 624
# 624
# 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████| 100/100 [00:00<00:00, 444.38it/s, loss=5.07e+3]
# 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████| 100/100 [00:00<00:00, 359.81it/s, loss=5.07e+3]
# 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████| 100/100 [00:00<00:00, 361.02it/s, loss=5.06e+3]
# 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████| 100/100 [00:00<00:00, 360.36it/s, loss=5.07e+3]
# 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████| 100/100 [00:00<00:00, 377.68it/s, loss=5.07e+3]
# 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████| 100/100 [00:00<00:00, 371.52it/s, loss=5.06e+3]
# 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████| 100/100 [00:00<00:00, 391.77it/s, loss=5.07e+3]
# 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████| 100/100 [00:00<00:00, 389.60it/s, loss=5.07e+3]
# 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████| 100/100 [00:00<00:00, 257.43it/s, loss=5.07e+3]
# 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████| 100/100 [00:00<00:00, 374.53it/s, loss=5.07e+3]
# CrowdBT | Percent: 10 |Acc: 0.7044 ± 0.0009 | WAcc: 0.7641 ± 0.0009 | Tau: 0.3860 ± 0.0017
# Unique performers: 624
# 624
# 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████| 100/100 [00:00<00:00, 346.65it/s, loss=5.07e+3]
# 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████| 100/100 [00:00<00:00, 314.57it/s, loss=5.07e+3]
# 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████| 100/100 [00:00<00:00, 357.07it/s, loss=5.06e+3]
# 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████| 100/100 [00:00<00:00, 400.80it/s, loss=5.07e+3]
# 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████| 100/100 [00:00<00:00, 266.99it/s, loss=5.07e+3]
# 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████| 100/100 [00:00<00:00, 319.71it/s, loss=5.06e+3]
# 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████| 100/100 [00:00<00:00, 366.26it/s, loss=5.07e+3]
# 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████| 100/100 [00:00<00:00, 370.50it/s, loss=5.07e+3]
# 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████| 100/100 [00:00<00:00, 292.06it/s, loss=5.07e+3]
# 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████| 100/100 [00:00<00:00, 355.35it/s, loss=5.07e+3]
# CrowdBT | Percent: 20 |Acc: 0.7044 ± 0.0009 | WAcc: 0.7641 ± 0.0009 | Tau: 0.3860 ± 0.0017
# Unique performers: 624
# 624
# 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████| 100/100 [00:00<00:00, 274.40it/s, loss=5.07e+3]
# 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████| 100/100 [00:00<00:00, 383.10it/s, loss=5.07e+3]
# 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████| 100/100 [00:00<00:00, 382.19it/s, loss=5.06e+3]
# 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████| 100/100 [00:00<00:00, 325.03it/s, loss=5.07e+3]
# 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████| 100/100 [00:00<00:00, 390.58it/s, loss=5.07e+3]
#  43%|████████████████████████████████████████████▎                                                          | 43/100 [00:00<00:00, 344.86it/s, loss=5.36e+3]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[16], line 18
#      16 try:
#      17     crowdbt_test = opt_fair.CrowdBT_3_0(data=PC_faceage, penalty=0, device=device, random_seed=seed)
# ---> 18     crowdbt_scores, _ = crowdbt_test.alternate_optim(size, K)
#      19     r_est = to_numpy(crowdbt_scores)
#      20     if np.isnan(r_est).any():
#
# File /workspace/main/spammers/passage/../../opt_fair.py:910, in CrowdBT_3_0.alternate_optim(self, num_items, num_reviewers, iters, lr_x, lr_y, tol, verbose)
#     908 loss_y = self.crowdbt_objective(scores.detach(), reliabilities)
#     909 loss_y.backward()
# --> 910 opt_y.step()
#     912 # Enforce [0, 1] constraint
#     913 reliabilities.data.clamp_(0.0, 1.0)
#
# File /usr/local/lib/python3.10/dist-packages/torch/optim/optimizer.py:517, in Optimizer.profile_hook_step.<locals>.wrapper(*args, **kwargs)
#     512         else:
#     513             raise RuntimeError(
#     514                 f"{func} must return None or a tuple of (new_args, new_kwargs), but got {result}."
#     515             )
# --> 517 out = func(*args, **kwargs)
#     518 self._optimizer_step_code()
#     520 # call optimizer step post hooks
#
# File /usr/local/lib/python3.10/dist-packages/torch/optim/optimizer.py:65, in _use_grad_for_differentiable.<locals>._use_grad(*args, **kwargs)
#      62 def _use_grad(*args: _P.args, **kwargs: _P.kwargs) -> _T:
#      63     import torch._dynamo
# ---> 65     self = cast(Optimizer, args[0])  # assume first positional arg is `self`
#      66     prev_grad = torch.is_grad_enabled()
#      67     try:
#      68         # Note on graph break below:
#      69         # we need to graph break to ensure that aot respects the no_grad annotation.
#    (...)
#      78         # graph break to allow the fully fused fwd-bwd-optimizer graph to be compiled.
#      79         # see https://github.com/pytorch/pytorch/issues/104053
#
# File /usr/lib/python3.10/typing.py:1737, in cast(typ, val)
#    1733     cls._is_runtime_protocol = True
#    1734     return cls
# -> 1737 def cast(typ, val):
#    1738     """Cast a value to a type.
#    1739
#    1740     This returns the value unchanged.  To the type checker this
#    (...)
#    1743     to be as fast as possible).
#    1744     """
#    1745     return val
#
# KeyboardInterrupt:
